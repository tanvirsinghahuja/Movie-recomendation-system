# %% [markdown]
# # Assignment: Try to segment foreground objects from the background

# %%
import cv2
import numpy as np

# %%
image = cv2.imread("/Users/tanvirsinghahuja/Desktop/ML II/Task5/Display_NFT_image.jpeg")

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# %%
(T, thresh) = cv2.threshold(blurred, 155, 255, cv2.THRESH_BINARY)

# %%
cv2.imshow("Thresholding of Image", np.hstack([gray, blurred, thresh]))
cv2.waitKey(0)
# Out:
# 27

# %%
from IPython import display
display.Image("/Users/tanvirsinghahuja/Desktop/Screen Shot 2021-11-23 at 8.13.21 PM.png")

# %%
(T, threshInv) = cv2.threshold(blurred, 155, 255, cv2.THRESH_BINARY_INV)

# %%
cv2.imshow("Thresholding of Images", np.hstack([gray, blurred, thresh, threshInv]))
cv2.waitKey(0)
# Out:
# 27

# %%
from IPython import display
display.Image("/Users/tanvirsinghahuja/Desktop/Screen Shot 2021-11-23 at 8.18.27 PM.png")

# %%
foreground = cv2.bitwise_and(image, image, mask = threshInv)
# Out:
# Error: Session cannot generate requests
# at S.executeCodeCell (/Users/tanvirsinghahuja/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:301742)
# at S.execute (/Users/tanvirsinghahuja/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:300732)
# at S.start (/Users/tanvirsinghahuja/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:296408)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/Users/tanvirsinghahuja/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:312326)
# at async t.CellExecutionQueue.start (/Users/tanvirsinghahuja/.vscode/extensions/ms-toolsai.jupyter-2021.10.1101450599/out/client/extension.js:66:311862)

# %%
cv2.imshow("Thresholding of Images", np.hstack([gray, blurred, thresh, threshInv]))
cv2.imshow("Foreground extraction", np.hstack([image, foreground]))
cv2.waitKey(0)
